# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a193-cloud/PYTHON-RECORD/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#checks if the string is a palindrome and prints 'Palindrome' if it is, otherwise prints 'Not Palindrome',
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for ch in set(input_str):
    count = input_str.count(ch)
    print(f"'{ch}' appears {count} times")
# Out:
# Enter a string: pradeep
# Not Palindrome
# 'a' appears 1 times
# 'd' appears 1 times
# 'r' appears 1 times
# 'e' appears 2 times
# 'p' appears 2 times
